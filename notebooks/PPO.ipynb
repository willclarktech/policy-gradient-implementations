# %% [markdown]
# <a href="https://colab.research.google.com/github/willclarktech/policy-gradient-implementations/blob/master/notebooks/PPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Policy Gradient Implementations: PPO

# %%
# %matplotlib inline
import os
from google.colab import files

# %%
algorithm = "ppo"
env = "InvertedPendulumBulletEnv-v0"
save_dir = "models"
seed = 123456

# %% [markdown]
# ## Install policy-gradient-implementations

# %%
# !if [ ! -d ./policy-gradient-implementations ]; then git clone --depth 1 --quiet https://github.com/willclarktech/policy-gradient-implementations.git; fi
os.chdir('./policy-gradient-implementations/')
print(f"Now in {os.getcwd()} at commit:")
# !git log --oneline -n 1
os.makedirs(f"{save_dir}/{algorithm}_{env}", exist_ok=True)
# !if [ ! -z COLAB_GPU ]; then pip install --no-warn-conflicts -r requirements.colab.txt 2>&1 >/dev/null; else pip install -r requirements.txt; fi
# Out:
# Now in /content/policy-gradient-implementations at commit:
# c34b0f8 (grafted, HEAD -> main, origin/main, origin/HEAD) :recycle: Detach action in PPO

# %% [markdown]
# ## Run experiment

# %%
import policy_gradients

policy_gradients.run({
    "algorithm": algorithm,
    "env_name": env,
    "n_episodes": 300,
    "log_period": 10,
    "save_dir": save_dir,
    "seed": seed,
    "alpha": 0.0001,
})
# Out:
# Using temporary directory /tmp/tmpiumou_9o
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Algorithm: ppo
# Hyperparameters:
# {'K': 4,
#  'N': 1,
#  'T': 10,
#  'algorithm': 'ppo',
#  'alpha': 0.0001,
#  'batch_size': 5,
#  'c1': 0.5,
#  'c2': 0.01,
#  'env_name': 'InvertedPendulumBulletEnv-v0',
#  'epsilon': 0.2,
#  'gamma': 0.99,
#  'hidden_features': [256, 256],
#  'lam': 0.95,
#  'log_period': 10,
#  'n_episodes': 300,
#  'seed': 123456}
# Starting training...
# [2021-02-12T19:12:39] Episode 10; Return 18.0; Average return 29.1
# [2021-02-12T19:12:42] Episode 20; Return 50.0; Average return 30.8
# [2021-02-12T19:12:44] Episode 30; Return 19.0; Average return 28.4
# [2021-02-12T19:12:46] Episode 40; Return 58.0; Average return 27.325
# [2021-02-12T19:12:50] Episode 50; Return 22.0; Average return 29.46
# [2021-02-12T19:12:52] Episode 60; Return 34.0; Average return 28.5
# [2021-02-12T19:12:55] Episode 70; Return 17.0; Average return 28.957142857142856
# [2021-02-12T19:12:57] Episode 80; Return 21.0; Average return 27.7
# [2021-02-12T19:13:00] Episode 90; Return 36.0; Average return 28.42222222222222
# [2021-02-12T19:13:02] Episode 100; Return 14.0; Average return 27.76
# [2021-02-12T19:13:05] Episode 110; Return 48.0; Average return 28.42
# [2021-02-12T19:13:09] Episode 120; Return 73.0; Average return 28.73
# [2021-02-12T19:13:12] Episode 130; Return 15.0; Average return 29.77
# [2021-02-12T19:13:16] Episode 140; Return 16.0; Average return 30.83
# [2021-02-12T19:13:17] Episode 150; Return 15.0; Average return 28.41
# [2021-02-12T19:13:19] Episode 160; Return 18.0; Average return 27.75
# [2021-02-12T19:13:21] Episode 170; Return 37.0; Average return 26.56
# [2021-02-12T19:13:23] Episode 180; Return 25.0; Average return 26.69
# [2021-02-12T19:13:25] Episode 190; Return 17.0; Average return 24.93
# [2021-02-12T19:13:27] Episode 200; Return 26.0; Average return 24.88
# [2021-02-12T19:13:30] Episode 210; Return 19.0; Average return 23.68
# [2021-02-12T19:13:33] Episode 220; Return 36.0; Average return 22.96
# [2021-02-12T19:13:37] Episode 230; Return 19.0; Average return 23.91
# [2021-02-12T19:13:42] Episode 240; Return 49.0; Average return 26.73
# [2021-02-12T19:13:48] Episode 250; Return 141.0; Average return 31.74
# [2021-02-12T19:13:56] Episode 260; Return 87.0; Average return 37.91
# [2021-02-12T19:14:02] Episode 270; Return 119.0; Average return 43.31
# [2021-02-12T19:14:10] Episode 280; Return 102.0; Average return 50.99
# [2021-02-12T19:14:20] Episode 290; Return 54.0; Average return 61.2
# [2021-02-12T19:14:34] Episode 300; Return 94.0; Average return 75.56
# Finished training
# Saving model to models...
# Successfully saved model

# %% [markdown]
# ## Download models

# %%
# !zip -r ./models.zip ./models/sac_InvertedPendulumBulletEnv-v0
files.download('./models.zip')
# Out:
# updating: models/sac_InvertedPendulumBulletEnv-v0/ (stored 0%)
# updating: models/sac_InvertedPendulumBulletEnv-v0/actor.zip (stored 0%)
# updating: models/sac_InvertedPendulumBulletEnv-v0/critic_1.zip (stored 0%)
# updating: models/sac_InvertedPendulumBulletEnv-v0/critic_2.zip (stored 0%)
# updating: models/sac_InvertedPendulumBulletEnv-v0/value.zip (stored 0%)
# updating: models/sac_InvertedPendulumBulletEnv-v0/hyperparameters.json (deflated 46%)
